# %% [markdown]
# ### Program 3: Vectorized Operations (No Loops)

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

# Vectorized operations
result = (arr * 3) + 10

print("Original Array:", arr)
print("Vectorized Result:", result)
# Out:
# Original Array: [1 2 3 4 5]
# Vectorized Result: [13 16 19 22 25]
