# %% [markdown]
# ### Program 1: Introduction to Pandas & Creating a Series

# %%
import pandas as pd

# Creating a Pandas Series
marks = pd.Series([85, 90, 78, 92])

print("Pandas Series:")
print(marks)
print("\nType:", type(marks))
# Out:
# Pandas Series:
# 0    85
# 1    90
# 2    78
# 3    92
# dtype: int64
#
# Type: <class 'pandas.core.series.Series'>
