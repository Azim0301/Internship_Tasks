# %% [markdown]
# ### Program 2: Creating a DataFrame from Dictionary

# %%
import pandas as pd

# Creating DataFrame
data = {
    "Name": ["Azim", "Dharm", "Bansi"],
    "Age": [21, 20, 19],
    "Marks": [85, 78, 92]
}

df = pd.DataFrame(data)

print("Pandas DataFrame:")
print(df)
# Out:
# Pandas DataFrame:
#     Name  Age  Marks
# 0   Azim   21     85
# 1  Dharm   20     78
# 2  Bansi   19     92
